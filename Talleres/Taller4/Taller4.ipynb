# %% [markdown]
# # IMM - Taller 4

# %% [markdown]
# ### Ejercicio para entregar en el campus

# %% [markdown]
# Realizar el gráfico del siguiente polinomio 𝑎𝑥3+𝑏𝑥2+𝑐𝑥+𝑑
# en el dominio [−20,20] y evaluado solo en números pares, para cualquier valor de los parámetros a, b, c y d.

# %% [markdown]
# **Solución**

# %%
#importamos el modulos de numpy (numeric python)
import numpy as np


#importamos del módulo matplotlib la libreria pyplot con el alias de plt 
#(esto no permitira graficar las funciones).
import matplotlib.pyplot as plt


#numero de divisiones del intervalo
n = 100

#--------------------------------------------
#defino el dominio como un arreglo tipo numpy
#--------------------------------------------
x = np.linspace(0, 2*np.pi, n)


#mostrar la lista de los valores de x
print("Los valores de la variable x son:\n ", x, "\n")



#Mediante el módulo numpy, evaluo la función sin(x) en todo el dominio.
#pasando el arreglo tipo numpy de x a la funcion de numpy sin. Esto arrojara 
#una ista de valores como resultado
#defino el dominio como un arreglo tipo numpy
#--------------------------------------------
y = np.sin(x)


#mostrar la lista de los valores de y
print("Los valores de la variable y son:\n ",   y, "\n")


#Graficando las dos listas de valores
plt.plot(x,y)


#poniendo nombres a de los ejes
plt.xlabel('x')
plt.ylabel('y')


#nombre del gráfico
plt.title('Grafico de y=sin(x)')

# ajustar tamaño de la figura (ancho y alto)
plt.rcParams['figure.figsize'] = [8, 6]
 
#Mostrando el gráfico
plt.show()
# Out:
# Los valores de la variable x son:
#   [0.         0.06346652 0.12693304 0.19039955 0.25386607 0.31733259
#  0.38079911 0.44426563 0.50773215 0.57119866 0.63466518 0.6981317
#  0.76159822 0.82506474 0.88853126 0.95199777 1.01546429 1.07893081
#  1.14239733 1.20586385 1.26933037 1.33279688 1.3962634  1.45972992
#  1.52319644 1.58666296 1.65012947 1.71359599 1.77706251 1.84052903
#  1.90399555 1.96746207 2.03092858 2.0943951  2.15786162 2.22132814
#  2.28479466 2.34826118 2.41172769 2.47519421 2.53866073 2.60212725
#  2.66559377 2.72906028 2.7925268  2.85599332 2.91945984 2.98292636
#  3.04639288 3.10985939 3.17332591 3.23679243 3.30025895 3.36372547
#  3.42719199 3.4906585  3.55412502 3.61759154 3.68105806 3.74452458
#  3.8079911  3.87145761 3.93492413 3.99839065 4.06185717 4.12532369
#  4.1887902  4.25225672 4.31572324 4.37918976 4.44265628 4.5061228
#  4.56958931 4.63305583 4.69652235 4.75998887 4.82345539 4.88692191
# ...

# %% [markdown]
# ### Gráfico de funciones usando el modulo numpy

# %% [markdown]
# Introducir el modulo numpy (numperic python): NumPy es una biblioteca para el lenguaje de programación Python que da soporte para crear vectores y matrices grandes multidimensionales, junto con una gran colección de funciones matemáticas de alto nivel para operar con ellas. Para ver mas informacion escribir (usando el gestor de paquetes pip: python installer packages):

# %%
! pip show numpy
# Out:
# Name: numpy
# Version: 1.20.1
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: /home/leon/anaconda3/lib/python3.8/site-packages
# Requires:
# Required-by: jitcxde-common, jitcode, vpython, tifffile, tables, statsmodels, seaborn, scipy, scikit-learn, scikit-image, PyWavelets, pyFFTW, pyerfa, patsy, pandas, numexpr, numba, mkl-random, mkl-fft, matplotlib, imageio, h5py, Bottleneck, bokeh, bkcharts, astropy

# %% [markdown]
# **1. Introducir el concepto de arreglo de numpy (numpy array):** Son listas en donde todas sus entradas son numeros reales. Con estos se definen vectores, matrices etc, los cuales pueden ser operados usando las reglas del algebra lineal.

# %%
#Ejemplos de de arreglos de numpy

#importamos el modulo numpy con un alias

import numpy as np


#Lista de numeros
Lista = [1,2,4]
print(type(Lista))



#La lista a arreglo de numpy
Arreglo = np.array([1,2,4])
print(type(Arreglo))


#DIFERENCIAS

print("Sumando dos listas   = ", Lista+Lista)

print("Sumando dos arreglos = ", Lista+Lista)


#NO SE PUEDE HACER (da un error la siguiente linea)
#print("Multiplicando dos listas   = ", Lista * Lista)



print("Multiplicando dos arreglos termino a termino (producto hadamard) =  ", Arreglo * Arreglo)


print("Multiplicando dos arreglos con producto escalar euclidiano        = ", Arreglo@Arreglo )



print("Multiplicando dos arreglos con producto escalar euclidiano        = ", np.dot(Arreglo,Arreglo)  )



#OPCIONAL: producto cruz...si ya lo han visto en A.L.
#print("Multiplicando dos arreglos con producto  vectorial (o curzado)    = ", np.cross(Arreglo,Arreglo)  )
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# Sumando dos listas   =  [1, 2, 4, 1, 2, 4]
# Sumando dos arreglos =  [1, 2, 4, 1, 2, 4]
# Multiplicando dos arreglos termino a termino (producto hadamard) =   [ 1  4 16]
# Multiplicando dos arreglos con producto escalar euclidiano        =  21
# Multiplicando dos arreglos con producto escalar euclidiano        =  21
# Multiplicando dos arreglos con producto  vectorial (o curzado)    =  [0 0 0]

# %% [markdown]
# ### Evaluacion de funciones sobre sobre arreglos

# %%
#Ejemplos

import numpy as np


#Generar un arreglo de forma automatica 


#Estructura: np.linspace( Inicio , final , #numero de puntos)




X = np.linspace( 0 , 2*np.pi , 10)
print("Arreglo de datos X = ", X)

#imprimir linea en blanco
print("\n")

#Podemos obtener la evaluacion de toda la funcion tan solo con evaluarla!
Y1 = np.sin(X)
Y2 = np.exp(X)
Y3 = np.sqrt(X)

print("Arreglo de datos y de la funcion sine = ", Y1 , "\n")
print("Arreglo de datos y de la funcion exponencial = ", Y2, "\n")
print("Arreglo de datos y de la funcion raiz cuadrada = " , Y3, "\n")




#Tambien funciona para funciones definidas por nosotros:
def Mifuncion(x):    
    return X + np.sin(X)**2  

Y4= Mifuncion(X)

print("Arreglo de datos y de mi funcion = " , Y4 , "\n")
# Out:
# Arreglo de datos X =  [0.         0.6981317  1.3962634  2.0943951  2.7925268  3.4906585
#  4.1887902  4.88692191 5.58505361 6.28318531]
#
#
# Arreglo de datos y de la funcion sine =  [ 0.00000000e+00  6.42787610e-01  9.84807753e-01  8.66025404e-01
#   3.42020143e-01 -3.42020143e-01 -8.66025404e-01 -9.84807753e-01
#  -6.42787610e-01 -2.44929360e-16]
#
# Arreglo de datos y de la funcion exponencial =  [  1.           2.00999393   4.04007559   8.1205274   16.32221075
#   32.80754449  65.9429652  132.5449596  266.41456388 535.49165552]
#
# Arreglo de datos y de la funcion raiz cuadrada =  [0.         0.83554276 1.1816359  1.44720251 1.67108552 1.86833041
#  2.04665342 2.21063835 2.3632718  2.50662827]
#
# Arreglo de datos y de mi funcion =  [0.         1.11130761 2.36610971 2.8443951  2.90950458 3.60763628
#  4.9387902  5.85676822 5.99822952 6.28318531]

# %% [markdown]
# **Ejemplo:** En este programa se muestra como graficar la función 𝑦(𝑥)=  exp( cos(x) ) en el dominio [0,2𝜋] mediante la implementación del módulo numpy y el módulo matplolib. La idea clave es utilizar arreglos tipo numpy para definir el dominio de una funciones y evaluarla sobre este arreglo de numeros.

# %%
#importamos el modulos de numpy (numeric python)
import numpy as np


#importamos del módulo matplotlib la libreria pyplot con el alias de plt 
#(esto no permitira graficar las funciones).
import matplotlib.pyplot as plt


#numero de divisiones del intervalo
n = 100

#--------------------------------------------
#defino el dominio como un arreglo tipo numpy
#--------------------------------------------
x = np.linspace(0, 2*np.pi, n)


#mostrar la lista de los valores de x
print("Los valores de la variable x son:\n ", x, "\n")



#Mediante el módulo numpy, evaluo la función sin(x)+ cos(x) en todo el dominio
#pasando el arreglo tipo numpy de x a la funcion. Esto arrojara 
#una lista de valores como resultado
#--------------------------------------------


def MiFuncionCompuesta(x):
    
    f = np.cos(x)
    g = np.exp( f )   
    
    return g



y = MiFuncionCompuesta(x)


#mostrar la lista de los valores de y
print("Los valores de la variable y son:\n ",   y, "\n")


#Graficando las dos listas de valores
plt.plot(x,y)


#poniendo nombres a de los ejes
plt.xlabel('x')
plt.ylabel('y')


#nombre del gráfico
plt.title('Grafico de y=sin(x)')

# ajustar tamaño de la figura (ancho y alto)
plt.rcParams['figure.figsize'] = [8, 6]
 
#Mostrando el gráfico
plt.show()
# Out:
# Los valores de la variable x son:
#   [0.         0.06346652 0.12693304 0.19039955 0.25386607 0.31733259
#  0.38079911 0.44426563 0.50773215 0.57119866 0.63466518 0.6981317
#  0.76159822 0.82506474 0.88853126 0.95199777 1.01546429 1.07893081
#  1.14239733 1.20586385 1.26933037 1.33279688 1.3962634  1.45972992
#  1.52319644 1.58666296 1.65012947 1.71359599 1.77706251 1.84052903
#  1.90399555 1.96746207 2.03092858 2.0943951  2.15786162 2.22132814
#  2.28479466 2.34826118 2.41172769 2.47519421 2.53866073 2.60212725
#  2.66559377 2.72906028 2.7925268  2.85599332 2.91945984 2.98292636
#  3.04639288 3.10985939 3.17332591 3.23679243 3.30025895 3.36372547
#  3.42719199 3.4906585  3.55412502 3.61759154 3.68105806 3.74452458
#  3.8079911  3.87145761 3.93492413 3.99839065 4.06185717 4.12532369
#  4.1887902  4.25225672 4.31572324 4.37918976 4.44265628 4.5061228
#  4.56958931 4.63305583 4.69652235 4.75998887 4.82345539 4.88692191
# ...

# %% [markdown]
# ### Guardando los datos de la funcion en un archivo

# %%
# hacer dos columnas, crear un arreglo
datosDosColumnas = np.column_stack(  (x, y)  )
print(datosDosColumnas)
 

# guardado de numpy!!!!
np.savetxt('archivo.dat', datosDosColumnas, header = "X-Columna, Y-Columna")
print ("listo!")
# Out:
# [[0.         2.71828183]
#  [0.06346652 2.71281455]
#  [0.12693304 2.69650048]
#  [0.19039955 2.66960013]
#  [0.25386607 2.63253879]
#  [0.31733259 2.58589356]
#  [0.38079911 2.53037606]
#  [0.44426563 2.46681178]
#  [0.50773215 2.39611668]
#  [0.57119866 2.31927244]
#  [0.63466518 2.23730106]
#  [0.6981317  2.15124005]
#  [0.76159822 2.06211888]
#  [0.82506474 1.97093768]
#  [0.88853126 1.87864856]
#  [0.95199777 1.78614008]
#  [1.01546429 1.6942251 ]
#  [1.07893081 1.60363203]
#  [1.14239733 1.51499935]
#  [1.20586385 1.42887329]
#  [1.26933037 1.34570814]
#  [1.33279688 1.26586912]
#  [1.3962634  1.18963695]
#  [1.45972992 1.11721413]
#  [1.52319644 1.04873211]
#  [1.58666296 0.98425924]
#  [1.65012947 0.92380898]
#  [1.71359599 0.86734814]
#  [1.77706251 0.81480483]
#  [1.84052903 0.76607606]
#  [1.90399555 0.72103474]
#  [1.96746207 0.67953596]
#  [2.03092858 0.64142269]
#  [2.0943951  0.60653066]
#  [2.15786162 0.57469256]
#  [2.22132814 0.54574159]
#  [2.28479466 0.51951441]
# ...

# %% [markdown]
# ### Lectura de datos

# %% [markdown]
# Lectura de un archivo de datos y graficado. Esto en el improbable caso de que sobre tiempo y el docente quiera adelanta, sin embargo, la siguiente clase comenzaremos con esto.

# %%
print("recuperando datos....")
datosRecuperados = np.loadtxt('archivo.dat')
print("los datos recuperados son:\n", datosRecuperados)


# obtner los datos por separado (Note automaticamente descarta los headers!!!)
x2 = datosRecuperados[:, 0] # toda la primera columna
y2 = datosRecuperados[:, 1] # toda la segunda columna


plt.plot(x2,y2)
plt.xlabel('eje de las x')
plt.ylabel('eje de las y')
plt.title('grafiquito de datos del archivo de texto plano:)')

plt.show()
# Out:
# recuperando datos....
# los datos recuperados son:
#  [[0.         2.71828183]
#  [0.06346652 2.71281455]
#  [0.12693304 2.69650048]
#  [0.19039955 2.66960013]
#  [0.25386607 2.63253879]
#  [0.31733259 2.58589356]
#  [0.38079911 2.53037606]
#  [0.44426563 2.46681178]
#  [0.50773215 2.39611668]
#  [0.57119866 2.31927244]
#  [0.63466518 2.23730106]
#  [0.6981317  2.15124005]
#  [0.76159822 2.06211888]
#  [0.82506474 1.97093768]
#  [0.88853126 1.87864856]
#  [0.95199777 1.78614008]
#  [1.01546429 1.6942251 ]
#  [1.07893081 1.60363203]
#  [1.14239733 1.51499935]
#  [1.20586385 1.42887329]
#  [1.26933037 1.34570814]
#  [1.33279688 1.26586912]
#  [1.3962634  1.18963695]
#  [1.45972992 1.11721413]
#  [1.52319644 1.04873211]
#  [1.58666296 0.98425924]
#  [1.65012947 0.92380898]
#  [1.71359599 0.86734814]
#  [1.77706251 0.81480483]
#  [1.84052903 0.76607606]
#  [1.90399555 0.72103474]
#  [1.96746207 0.67953596]
#  [2.03092858 0.64142269]
#  [2.0943951  0.60653066]
#  [2.15786162 0.57469256]
# ...
